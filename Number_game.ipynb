# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinushavenkadesh8/SCT_SD_2/blob/main/Number_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def guess_the_number():
    # 1. Generate a random number between 1 and 100
    secret_number = random.randint(1, 100)
    attempts = 0

    print("Welcome to the Number Guessing Game!")
    print("I'm thinking of a number between 1 and 100.")

    # 2. Start a loop so the user can keep guessing
    while True:
        try:
            # 3. Prompt the user for their guess
            guess = int(input("Enter your guess: "))
            attempts += 1

            # 4. Compare the guess to the secret number
            if guess < secret_number:
                print("Too low! Try again.")
            elif guess > secret_number:
                print("Too high! Try again.")
            else:
                print(f"Congratulations! You guessed it in {attempts} attempts.")
                break # Exit the loop when they get it right

        except ValueError:
            print("Please enter a valid whole number.")

if __name__ == "__main__":
    guess_the_number()
# Out:
# Welcome to the Number Guessing Game!
# I'm thinking of a number between 1 and 100.
# Enter your guess: 88
# Too high! Try again.
# Enter your guess: 56
# Too high! Try again.
# Enter your guess: 12
# Too low! Try again.
# Enter your guess: 34
# Too high! Try again.
# Enter your guess: 20
# Too low! Try again.
# Enter your guess: 25
# Too low! Try again.
# Enter your guess: 22
# Too low! Try again.
# Enter your guess: 39
# Too high! Try again.
# Enter your guess: 30
# Too low! Try again.
# Enter your guess: 32
# Too high! Try again.
# Enter your guess: 31
# Congratulations! You guessed it in 11 attempts.
